# %% [markdown]
# # U.S. Medical Insurance Costs

# %% [markdown]
# For this project I will be using US medical insurance data and performing a basic analysis on that data. The data contains information on 1338 insurance applicants and is initially held in a CSV. The information given includes:
# * Age
# * Sex
# * BMI
# * Children
# * Smoker
# * Region
# * Insurance Cost
#
# I'm going to initally generate a summary of the data, followed by a deeper dive into what the data tells us. After completing the python fundamentals section of the data science career path, I have realised I am lacking knowledge on Classes and so will utilise them in this project to gain a deeper understanding. Since the data is given in CSV format I will first import the csv module and convert the .csv data to a list for each column in the .csv.

# %% [markdown]
# ### Data Cleaning

# %%
import csv

# %%
def convert_to_list(filename, column_name):
    """ A helper function to convert the csv data in 'file' to a dictionary where the column names of the .csv are
        the keys and the data the values. """
    lst = list()
    with open(filename) as file:
        file_dict = csv.DictReader(file)
        for row in file_dict:
            lst.append(row[column_name])
    return lst

# %% [markdown]
# Now we have a helper function to convert the information given in each column of the csv to a list, we can create 7 lists to hold the 7 columns of data.

# %%
age = convert_to_list("insurance.csv", "age")
sex = convert_to_list("insurance.csv", "sex")
bmi = convert_to_list("insurance.csv", "bmi")
children = convert_to_list("insurance.csv", "children")
smoker = convert_to_list("insurance.csv", "smoker")
region = convert_to_list("insurance.csv", "region")
insurance_cost = convert_to_list("insurance.csv", "charges")

# %% [markdown]
# As said above, I would like to practise using Classes in this project. But first, what do we actually want to get out of the data?
# * A summary of the data (average age, no. males/females, average bmi, average no. children, average no. (non) smokers, most frequent region and the average insurance cost)
# * The difference in cost between: males/females, smokers/non-smokers, children/no-children, regions.
# * The average age of applicants with 1, 2, 3... children

# %% [markdown]
# ### Creating our Class

# %%
class InsuranceData:
    def __init__(self, age, sex, bmi, children, smoker, region, insurance_cost):
        self.age = age
        self.sex = sex
        self.bmi = bmi
        self.children = children
        self.smoker = smoker
        self.region = region
        self.insurance_cost = insurance_cost
    
    def average_age(self):
        """ Works out the average age of the insurance applicants. """
        sum_ages = 0
        for age in self.age:
            sum_ages += int(age)
        average_age = sum_ages / len(self.age)
        return int(average_age)
    
    def no_of_females(self):
        """ Counts the number of females within the dataset. """
        females = 0
        for sex in self.sex:
            if sex == "female":
                females += 1
        return females
    
    def no_of_males(self):
        """ Counts the number of males within the dataset. """
        males = 0
        for sex in self.sex:
            if sex == "male":
                males += 1
        return males
    
    def average_bmi(self):
        """ Works out the average bmi of the dataset. """
        sum_bmis = 0
        for bmi in self.bmi:
            sum_bmis += float(bmi)
        avg_bmi = sum_bmis / len(self.bmi)
        return round(avg_bmi, 1)
    
    def average_children(self):
        """ Works out the average no. of children of the applicants. """
        sum_children = 0
        for children in self.children:
            sum_children += int(children)
        avg_children = sum_children / len(self.children)
        return int(avg_children)
    
    def no_smoker(self):
        """ Works out the no. of smokers in the dataset. """
        sum_smokers = 0
        for smoker in self.smoker:
            if smoker == "yes":
                sum_smokers += 1
        return sum_smokers
    
    def no_non_smoker(self):
        """ Works out the no. of non-smokers in the dataset. """
        sum_non_smokers = 0
        for smoker in self.smoker:
            if smoker == "no":
                sum_non_smokers += 1
        return sum_non_smokers
    
    def most_frequent_region(self):
        """ Counts and returns the region applicants are most frequently from. """
        northeast_count = self.region.count("northeast")
        northwest_count = self.region.count("northwest")
        southeast_count = self.region.count("southeast")
        southwest_count = self.region.count("southwest")
        if northeast_count > northwest_count and northeast_count > southeast_count and northeast_count > southwest_count:
            return "northeast"
        elif northwest_count > northeast_count and northwest_count > southeast_count and northwest_count > southwest_count:
            return "northwest"
        elif southeast_count > northwest_count and southeast_count > northeast_count and southeast_count > southwest_count:
            return "southeast"
        else:
            return "southwest"
    
    def average_cost(self):
        """ Calculates the average cost for insurance. """
        sum_cost = 0
        for cost in self.insurance_cost:
            sum_cost += float(cost)
        average_cost = sum_cost / len(self.insurance_cost)
        return round(average_cost, 2)
    
    def data_summary(self):
        """ Returns a dictionary summary of the data, including: average age, no. males/females, average bmi, 
            average no. children, no. (non) smokers, most frequent region and the average insurance 
            cost. """
        summary_dict = {}
        summary_dict["Average Age"] = self.average_age()
        summary_dict["No. of Males"] = self.no_of_males()
        summary_dict["No. of Females"] = self.no_of_females()
        summary_dict["Average BMI"] = self.average_bmi()
        summary_dict["Average no. of Children"] = self.average_children()
        summary_dict["No. of Smokers"] = self.no_smoker()
        summary_dict["No. of Non-Smokers"] = self.no_non_smoker()
        summary_dict["Most Frequent Region"] = self.most_frequent_region()
        summary_dict["Average Cost"] = self.average_cost()
        return summary_dict
    
    def create_dictionary(self):
        """ Creates a dictionary of the applicants, where each key is an arbituarary count and the values are the
            applicant data. """
        applicant_dict = {}
        for i in range(len(self.age)):
            applicant_dict[i] = [self.age[i], self.sex[i], self.bmi[i], self.children[i], self.smoker[i], self.region[i], self.insurance_cost[i]]
        return applicant_dict
    
    def compare_cost_sex(self):
        """ Returns the difference in average insurance cost between males and females. """
        applicant_dict = self.create_dictionary()
        male_costs_sum = 0
        female_costs_sum = 0
        for lst in applicant_dict.values():
            if lst[1] == "male":
                male_costs_sum += float(lst[6]) 
            else:
                female_costs_sum += float(lst[6])
        average_male_cost = male_costs_sum / self.no_of_males()
        average_female_cost = male_costs_sum / self.no_of_females()
        diff_cost = round(average_male_cost - average_female_cost, 2)
        return f"The difference between the average cost of insurance for males and females is ${diff_cost}"
    
    def compare_cost_smoker(self):
        """ Returns the difference in average cost of insurance between smokers and non-smokers. """
        applicant_dict = self.create_dictionary()
        smokers_cost_sum = 0
        non_smokers_cost_sum = 0
        for lst in applicant_dict.values():
            if lst[4] == "yes":
                smokers_cost_sum += float(lst[6])
            else:
                non_smokers_cost_sum += float(lst[6])
        average_smokers_cost = smokers_cost_sum / self.no_smoker()
        average_non_smokers_cost = non_smokers_cost_sum / self.no_non_smoker()
        diff_cost = round(average_smokers_cost - average_non_smokers_cost, 2)
        return f"The difference between the average cost of insurance for smokers and non-smokers is ${diff_cost}"
    
    def compare_cost_children(self):
        """ Creates a dictionary where the keys are the no. of children and the values are the average cost of 
            insurance. """
        sum_costs = 0
        applicant_dict = self.create_dictionary()
        children_list = [int(i) for i in self.children]
        max_no_children = max(children_list)
        children_cost_dict = {key: [] for key in range(max_no_children+1)}
        for key in children_cost_dict.keys():
            for lst in applicant_dict.values():
                if int(lst[3]) == key:
                    children_cost_dict[key].append(float(lst[6]))
        for key in children_cost_dict.keys():
            for value in children_cost_dict[key]:
                sum_costs += value
            average_cost = sum_costs / len(children_cost_dict[key])
            sum_costs = 0
            children_cost_dict[key] = round(average_cost, 2)
        return children_cost_dict
    
    def compare_cost_region(self):
        """ Creates a dictionary where the keys are the region and the value is the average cost for that region. 
        """
        applicant_dict = self.create_dictionary()
        region_cost_dict = {"northeast": 0, "northwest": 0, "southeast": 0, "southwest": 0}
        northeast_count = self.region.count("northeast")
        northwest_count = self.region.count("northwest")
        southeast_count = self.region.count("southeast")
        southwest_count = self.region.count("southwest")
        for key in region_cost_dict.keys():
            for value in applicant_dict.values():
                if key == value[5]:
                    region_cost_dict[key] += float(value[6])
        region_cost_dict["northeast"] /= northeast_count
        region_cost_dict["northwest"] /= northwest_count
        region_cost_dict["southeast"] /= southeast_count
        region_cost_dict["southwest"] /= southwest_count
        for key in region_cost_dict.keys():
            region_cost_dict[key] = round(region_cost_dict[key], 2)
        return region_cost_dict
    
    def average_age_with_children(self):
        """ Creates a dictionary where the keys are the no. of children and the values are the average age of 
            applicants with that no. of children. """
        sum_ages = 0
        applicant_dict = self.create_dictionary()
        children_list = [int(i) for i in self.children]
        max_no_children = max(children_list)
        children_ages_dict = {key: [] for key in range(max_no_children+1)}
        for key in children_ages_dict.keys():
            for lst in applicant_dict.values():
                if int(lst[3]) == key:
                    children_ages_dict[key].append(int(lst[0]))
        for key in children_ages_dict.keys():
            for value in children_ages_dict[key]:
                sum_ages += value
            average_age = sum_ages / len(children_ages_dict[key])
            sum_ages = 0
            children_ages_dict[key] = round(average_age, 2)
        return children_ages_dict

# %% [markdown]
# Now we have created our class we can get into analysing the data. First lets create our insurance data object using the the lists we created earlier:

# %%
data = InsuranceData(age, sex, bmi, children, smoker, region, insurance_cost)

# %% [markdown]
# ### Data Summary

# %% [markdown]
# We want to get a high level summary of the data, lets use the data_summary method we created:

# %%
data.data_summary()
# Out:
# {'Average Age': 39,
#  'No. of Males': 676,
#  'No. of Females': 662,
#  'Average BMI': 30.7,
#  'Average no. of Children': 1,
#  'No. of Smokers': 274,
#  'No. of Non-Smokers': 1064,
#  'Most Frequent Region': 'southeast',
#  'Average Cost': 13270.42}

# %% [markdown]
# This dictionary gives us a clear indication as to how the data is made up. We can see from the 1,338 applicants, 676 were male and 662 were female, so we can clearly see there is a roughly even representation of males and females within the data. The average age of the applicants was 39, average BMI 30.7 and applicants had an average of 1 child. We can see there is a larger representation of non-smokers to smokers, 1064 to 274, and the most frequent region was the Southeast. Of the 1,338 applicants the average cost of insurance was $13,270.42.
#
# By creating this dictionary we have managed to quickly and easily analyse the make-up of our data ready for further analysis.
#
# Now we have a summary of the data, lets look further into the data, to see what we can extract. We want to see how the insurance cost differs between people of different sex, smoker status, no. of children and region.

# %% [markdown]
# ### Comparing the Data

# %%
sex_comparison = data.compare_cost_sex()
sex_comparison
# Out:
# 'The difference between the average cost of insurance for males and females is $-295.16'

# %% [markdown]
# From our analysis, males paid an average of $295.16 less for there insurance than females. This would lead us nicley into some further analysis as to why that was the case.

# %%
smoker_comparison = data.compare_cost_smoker()
smoker_comparison
# Out:
# 'The difference between the average cost of insurance for smokers and non-smokers is $23615.96'

# %% [markdown]
# Unsurpisingly smokers paid an average of $23,615.96 more for insurance than non-smokers.

# %%
children_comparison = data.compare_cost_children()
children_comparison
# Out:
# {0: 12365.98, 1: 12731.17, 2: 15073.56, 3: 15355.32, 4: 13850.66, 5: 8786.04}

# %% [markdown]
# The average cost of insurance increases from 0 to 3 children and then decreases to 5 children.

# %%
region_comparison = data.compare_cost_region()
region_comparison
# Out:
# {'northeast': 13406.38,
#  'northwest': 12417.58,
#  'southeast': 14735.41,
#  'southwest': 12346.94}

# %% [markdown]
# Of the four regions, the Southeast had the highest average insurance cost at $14,735.41

# %% [markdown]
# The data can clearly be analysed in much greater detail, and it is clear that each variable has different effect on the average cost paid. However, the above comparisons give us a platform to look into why the comparisons are as they are.
#
# Finally, we can present the data all together as one using the create_dictionary() method. The data will be displayed as a dictionary where each key represents an applicant (given a psuedo ID no.) and the value is the data for that applicant:

# %%
data_dict = data.create_dictionary()
data_dict
# Out:
# {0: ['19', 'female', '27.9', '0', 'yes', 'southwest', '16884.924'],
#  1: ['18', 'male', '33.77', '1', 'no', 'southeast', '1725.5523'],
#  2: ['28', 'male', '33', '3', 'no', 'southeast', '4449.462'],
#  3: ['33', 'male', '22.705', '0', 'no', 'northwest', '21984.47061'],
#  4: ['32', 'male', '28.88', '0', 'no', 'northwest', '3866.8552'],
#  5: ['31', 'female', '25.74', '0', 'no', 'southeast', '3756.6216'],
#  6: ['46', 'female', '33.44', '1', 'no', 'southeast', '8240.5896'],
#  7: ['37', 'female', '27.74', '3', 'no', 'northwest', '7281.5056'],
#  8: ['37', 'male', '29.83', '2', 'no', 'northeast', '6406.4107'],
#  9: ['60', 'female', '25.84', '0', 'no', 'northwest', '28923.13692'],
#  10: ['25', 'male', '26.22', '0', 'no', 'northeast', '2721.3208'],
#  11: ['62', 'female', '26.29', '0', 'yes', 'southeast', '27808.7251'],
#  12: ['23', 'male', '34.4', '0', 'no', 'southwest', '1826.843'],
#  13: ['56', 'female', '39.82', '0', 'no', 'southeast', '11090.7178'],
#  14: ['27', 'male', '42.13', '0', 'yes', 'southeast', '39611.7577'],
#  15: ['19', 'male', '24.6', '1', 'no', 'southwest', '1837.237'],
#  16: ['52', 'female', '30.78', '1', 'no', 'northeast', '10797.3362'],
#  17: ['23', 'male', '23.845', '0', 'no', 'northeast', '2395.17155'],
#  18: ['56', 'male', '40.3', '0', 'no', 'southwest', '10602.385'],
#  19: ['30', 'male', '35.3', '0', 'yes', 'southwest', '36837.467'],
#  20: ['60', 'female', '36.005', '0', 'no', 'northeast', '13228.84695'],
#  21: ['30', 'female', '32.4', '1', 'no', 'southwest', '4149.736'],
#  22: ['18', 'male', '34.1', '0', 'no', 'southeast', '1137.011'],
#  23: ['34', 'female', '31.92', '1', 'yes', 'northeast', '37701.8768'],
#  24: ['37', 'male', '28.025', '2', 'no', 'northwest', '6203.90175'],
#  25: ['59', 'female', '27.72', '3', 'no', 'southeast', '14001.1338'],
#  26: ['63', 'female', '23.085', '0', 'no', 'northeast', '14451.83515'],
#  27: ['55', 'female', '32.775', '2', 'no', 'northwest', '12268.63225'],
#  28: ['23', 'male', '17.385', '1', 'no', 'northwest', '2775.19215'],
#  29: ['31', 'male', '36.3', '2', 'yes', 'southwest', '38711'],
#  30: ['22', 'male', '35.6', '0', 'yes', 'southwest', '35585.576'],
#  31: ['18', 'female', '26.315', '0', 'no', 'northeast', '2198.18985'],
#  32: ['19', 'female', '28.6', '5', 'no', 'southwest', '4687.797'],
#  33: ['63', 'male', '28.31', '0', 'no', 'northwest', '13770.0979'],
#  34: ['28', 'male', '36.4', '1', 'yes', 'southwest', '51194.55914'],
#  35: ['19', 'male', '20.425', '0', 'no', 'northwest', '1625.43375'],
#  36: ['62', 'female', '32.965', '3', 'no', 'northwest', '15612.19335'],
#  37: ['26', 'male', '20.8', '0', 'no', 'southwest', '2302.3'],
#  38: ['35', 'male', '36.67', '1', 'yes', 'northeast', '39774.2763'],
#  39: ['60', 'male', '39.9', '0', 'yes', 'southwest', '48173.361'],
#  40: ['24', 'female', '26.6', '0', 'no', 'northeast', '3046.062'],
#  41: ['31', 'female', '36.63', '2', 'no', 'southeast', '4949.7587'],
#  42: ['41', 'male', '21.78', '1', 'no', 'southeast', '6272.4772'],
#  43: ['37', 'female', '30.8', '2', 'no', 'southeast', '6313.759'],
#  44: ['38', 'male', '37.05', '1', 'no', 'northeast', '6079.6715'],
#  45: ['55', 'male', '37.3', '0', 'no', 'southwest', '20630.28351'],
#  46: ['18', 'female', '38.665', '2', 'no', 'northeast', '3393.35635'],
#  47: ['28', 'female', '34.77', '0', 'no', 'northwest', '3556.9223'],
#  48: ['60', 'female', '24.53', '0', 'no', 'southeast', '12629.8967'],
#  49: ['36', 'male', '35.2', '1', 'yes', 'southeast', '38709.176'],
#  50: ['18', 'female', '35.625', '0', 'no', 'northeast', '2211.13075'],
#  51: ['21', 'female', '33.63', '2', 'no', 'northwest', '3579.8287'],
#  52: ['48', 'male', '28', '1', 'yes', 'southwest', '23568.272'],
#  53: ['36', 'male', '34.43', '0', 'yes', 'southeast', '37742.5757'],
#  54: ['40', 'female', '28.69', '3', 'no', 'northwest', '8059.6791'],
#  55: ['58', 'male', '36.955', '2', 'yes', 'northwest', '47496.49445'],
#  56: ['58', 'female', '31.825', '2', 'no', 'northeast', '13607.36875'],
#  57: ['18', 'male', '31.68', '2', 'yes', 'southeast', '34303.1672'],
#  58: ['53', 'female', '22.88', '1', 'yes', 'southeast', '23244.7902'],
#  59: ['34', 'female', '37.335', '2', 'no', 'northwest', '5989.52365'],
#  60: ['43', 'male', '27.36', '3', 'no', 'northeast', '8606.2174'],
#  61: ['25', 'male', '33.66', '4', 'no', 'southeast', '4504.6624'],
#  62: ['64', 'male', '24.7', '1', 'no', 'northwest', '30166.61817'],
#  63: ['28', 'female', '25.935', '1', 'no', 'northwest', '4133.64165'],
#  64: ['20', 'female', '22.42', '0', 'yes', 'northwest', '14711.7438'],
#  65: ['19', 'female', '28.9', '0', 'no', 'southwest', '1743.214'],
#  66: ['61', 'female', '39.1', '2', 'no', 'southwest', '14235.072'],
#  67: ['40', 'male', '26.315', '1', 'no', 'northwest', '6389.37785'],
#  68: ['40', 'female', '36.19', '0', 'no', 'southeast', '5920.1041'],
#  69: ['28', 'male', '23.98', '3', 'yes', 'southeast', '17663.1442'],
#  70: ['27', 'female', '24.75', '0', 'yes', 'southeast', '16577.7795'],
#  71: ['31', 'male', '28.5', '5', 'no', 'northeast', '6799.458'],
#  72: ['53', 'female', '28.1', '3', 'no', 'southwest', '11741.726'],
#  73: ['58', 'male', '32.01', '1', 'no', 'southeast', '11946.6259'],
#  74: ['44', 'male', '27.4', '2', 'no', 'southwest', '7726.854'],
#  75: ['57', 'male', '34.01', '0', 'no', 'northwest', '11356.6609'],
#  76: ['29', 'female', '29.59', '1', 'no', 'southeast', '3947.4131'],
#  77: ['21', 'male', '35.53', '0', 'no', 'southeast', '1532.4697'],
#  78: ['22', 'female', '39.805', '0', 'no', 'northeast', '2755.02095'],
#  79: ['41', 'female', '32.965', '0', 'no', 'northwest', '6571.02435'],
#  80: ['31', 'male', '26.885', '1', 'no', 'northeast', '4441.21315'],
#  81: ['45', 'female', '38.285', '0', 'no', 'northeast', '7935.29115'],
#  82: ['22', 'male', '37.62', '1', 'yes', 'southeast', '37165.1638'],
#  83: ['48', 'female', '41.23', '4', 'no', 'northwest', '11033.6617'],
#  84: ['37', 'female', '34.8', '2', 'yes', 'southwest', '39836.519'],
#  85: ['45', 'male', '22.895', '2', 'yes', 'northwest', '21098.55405'],
#  86: ['57', 'female', '31.16', '0', 'yes', 'northwest', '43578.9394'],
#  87: ['56', 'female', '27.2', '0', 'no', 'southwest', '11073.176'],
#  88: ['46', 'female', '27.74', '0', 'no', 'northwest', '8026.6666'],
#  89: ['55', 'female', '26.98', '0', 'no', 'northwest', '11082.5772'],
#  90: ['21', 'female', '39.49', '0', 'no', 'southeast', '2026.9741'],
#  91: ['53', 'female', '24.795', '1', 'no', 'northwest', '10942.13205'],
#  92: ['59', 'male', '29.83', '3', 'yes', 'northeast', '30184.9367'],
#  93: ['35', 'male', '34.77', '2', 'no', 'northwest', '5729.0053'],
#  94: ['64', 'female', '31.3', '2', 'yes', 'southwest', '47291.055'],
#  95: ['28', 'female', '37.62', '1', 'no', 'southeast', '3766.8838'],
#  96: ['54', 'female', '30.8', '3', 'no', 'southwest', '12105.32'],
#  97: ['55', 'male', '38.28', '0', 'no', 'southeast', '10226.2842'],
#  98: ['56', 'male', '19.95', '0', 'yes', 'northeast', '22412.6485'],
#  99: ['38', 'male', '19.3', '0', 'yes', 'southwest', '15820.699'],
#  100: ['41', 'female', '31.6', '0', 'no', 'southwest', '6186.127'],
#  101: ['30', 'male', '25.46', '0', 'no', 'northeast', '3645.0894'],
#  102: ['18', 'female', '30.115', '0', 'no', 'northeast', '21344.8467'],
#  103: ['61', 'female', '29.92', '3', 'yes', 'southeast', '30942.1918'],
#  104: ['34', 'female', '27.5', '1', 'no', 'southwest', '5003.853'],
#  105: ['20', 'male', '28.025', '1', 'yes', 'northwest', '17560.37975'],
#  106: ['19', 'female', '28.4', '1', 'no', 'southwest', '2331.519'],
#  107: ['26', 'male', '30.875', '2', 'no', 'northwest', '3877.30425'],
#  108: ['29', 'male', '27.94', '0', 'no', 'southeast', '2867.1196'],
#  109: ['63', 'male', '35.09', '0', 'yes', 'southeast', '47055.5321'],
#  110: ['54', 'male', '33.63', '1', 'no', 'northwest', '10825.2537'],
#  111: ['55', 'female', '29.7', '2', 'no', 'southwest', '11881.358'],
#  112: ['37', 'male', '30.8', '0', 'no', 'southwest', '4646.759'],
#  113: ['21', 'female', '35.72', '0', 'no', 'northwest', '2404.7338'],
#  114: ['52', 'male', '32.205', '3', 'no', 'northeast', '11488.31695'],
#  115: ['60', 'male', '28.595', '0', 'no', 'northeast', '30259.99556'],
#  116: ['58', 'male', '49.06', '0', 'no', 'southeast', '11381.3254'],
#  117: ['29', 'female', '27.94', '1', 'yes', 'southeast', '19107.7796'],
#  118: ['49', 'female', '27.17', '0', 'no', 'southeast', '8601.3293'],
#  119: ['37', 'female', '23.37', '2', 'no', 'northwest', '6686.4313'],
#  120: ['44', 'male', '37.1', '2', 'no', 'southwest', '7740.337'],
#  121: ['18', 'male', '23.75', '0', 'no', 'northeast', '1705.6245'],
#  122: ['20', 'female', '28.975', '0', 'no', 'northwest', '2257.47525'],
#  123: ['44', 'male', '31.35', '1', 'yes', 'northeast', '39556.4945'],
#  124: ['47', 'female', '33.915', '3', 'no', 'northwest', '10115.00885'],
#  125: ['26', 'female', '28.785', '0', 'no', 'northeast', '3385.39915'],
#  126: ['19', 'female', '28.3', '0', 'yes', 'southwest', '17081.08'],
#  127: ['52', 'female', '37.4', '0', 'no', 'southwest', '9634.538'],
#  128: ['32', 'female', '17.765', '2', 'yes', 'northwest', '32734.1863'],
#  129: ['38', 'male', '34.7', '2', 'no', 'southwest', '6082.405'],
#  130: ['59', 'female', '26.505', '0', 'no', 'northeast', '12815.44495'],
#  131: ['61', 'female', '22.04', '0', 'no', 'northeast', '13616.3586'],
#  132: ['53', 'female', '35.9', '2', 'no', 'southwest', '11163.568'],
#  133: ['19', 'male', '25.555', '0', 'no', 'northwest', '1632.56445'],
#  134: ['20', 'female', '28.785', '0', 'no', 'northeast', '2457.21115'],
#  135: ['22', 'female', '28.05', '0', 'no', 'southeast', '2155.6815'],
#  136: ['19', 'male', '34.1', '0', 'no', 'southwest', '1261.442'],
#  137: ['22', 'male', '25.175', '0', 'no', 'northwest', '2045.68525'],
#  138: ['54', 'female', '31.9', '3', 'no', 'southeast', '27322.73386'],
#  139: ['22', 'female', '36', '0', 'no', 'southwest', '2166.732'],
#  140: ['34', 'male', '22.42', '2', 'no', 'northeast', '27375.90478'],
#  141: ['26', 'male', '32.49', '1', 'no', 'northeast', '3490.5491'],
#  142: ['34', 'male', '25.3', '2', 'yes', 'southeast', '18972.495'],
#  143: ['29', 'male', '29.735', '2', 'no', 'northwest', '18157.876'],
#  144: ['30', 'male', '28.69', '3', 'yes', 'northwest', '20745.9891'],
#  145: ['29', 'female', '38.83', '3', 'no', 'southeast', '5138.2567'],
#  146: ['46', 'male', '30.495', '3', 'yes', 'northwest', '40720.55105'],
#  147: ['51', 'female', '37.73', '1', 'no', 'southeast', '9877.6077'],
#  148: ['53', 'female', '37.43', '1', 'no', 'northwest', '10959.6947'],
#  149: ['19', 'male', '28.4', '1', 'no', 'southwest', '1842.519'],
#  150: ['35', 'male', '24.13', '1', 'no', 'northwest', '5125.2157'],
#  151: ['48', 'male', '29.7', '0', 'no', 'southeast', '7789.635'],
#  152: ['32', 'female', '37.145', '3', 'no', 'northeast', '6334.34355'],
#  153: ['42', 'female', '23.37', '0', 'yes', 'northeast', '19964.7463'],
#  154: ['40', 'female', '25.46', '1', 'no', 'northeast', '7077.1894'],
#  155: ['44', 'male', '39.52', '0', 'no', 'northwest', '6948.7008'],
#  156: ['48', 'male', '24.42', '0', 'yes', 'southeast', '21223.6758'],
#  157: ['18', 'male', '25.175', '0', 'yes', 'northeast', '15518.18025'],
#  158: ['30', 'male', '35.53', '0', 'yes', 'southeast', '36950.2567'],
#  159: ['50', 'female', '27.83', '3', 'no', 'southeast', '19749.38338'],
#  160: ['42', 'female', '26.6', '0', 'yes', 'northwest', '21348.706'],
#  161: ['18', 'female', '36.85', '0', 'yes', 'southeast', '36149.4835'],
#  162: ['54', 'male', '39.6', '1', 'no', 'southwest', '10450.552'],
#  163: ['32', 'female', '29.8', '2', 'no', 'southwest', '5152.134'],
#  164: ['37', 'male', '29.64', '0', 'no', 'northwest', '5028.1466'],
#  165: ['47', 'male', '28.215', '4', 'no', 'northeast', '10407.08585'],
#  166: ['20', 'female', '37', '5', 'no', 'southwest', '4830.63'],
#  167: ['32', 'female', '33.155', '3', 'no', 'northwest', '6128.79745'],
#  168: ['19', 'female', '31.825', '1', 'no', 'northwest', '2719.27975'],
#  169: ['27', 'male', '18.905', '3', 'no', 'northeast', '4827.90495'],
#  170: ['63', 'male', '41.47', '0', 'no', 'southeast', '13405.3903'],
#  171: ['49', 'male', '30.3', '0', 'no', 'southwest', '8116.68'],
#  172: ['18', 'male', '15.96', '0', 'no', 'northeast', '1694.7964'],
#  173: ['35', 'female', '34.8', '1', 'no', 'southwest', '5246.047'],
#  174: ['24', 'female', '33.345', '0', 'no', 'northwest', '2855.43755'],
#  175: ['63', 'female', '37.7', '0', 'yes', 'southwest', '48824.45'],
#  176: ['38', 'male', '27.835', '2', 'no', 'northwest', '6455.86265'],
#  177: ['54', 'male', '29.2', '1', 'no', 'southwest', '10436.096'],
#  178: ['46', 'female', '28.9', '2', 'no', 'southwest', '8823.279'],
#  179: ['41', 'female', '33.155', '3', 'no', 'northeast', '8538.28845'],
#  180: ['58', 'male', '28.595', '0', 'no', 'northwest', '11735.87905'],
#  181: ['18', 'female', '38.28', '0', 'no', 'southeast', '1631.8212'],
#  182: ['22', 'male', '19.95', '3', 'no', 'northeast', '4005.4225'],
#  183: ['44', 'female', '26.41', '0', 'no', 'northwest', '7419.4779'],
#  184: ['44', 'male', '30.69', '2', 'no', 'southeast', '7731.4271'],
#  185: ['36', 'male', '41.895', '3', 'yes', 'northeast', '43753.33705'],
#  186: ['26', 'female', '29.92', '2', 'no', 'southeast', '3981.9768'],
#  187: ['30', 'female', '30.9', '3', 'no', 'southwest', '5325.651'],
#  188: ['41', 'female', '32.2', '1', 'no', 'southwest', '6775.961'],
#  189: ['29', 'female', '32.11', '2', 'no', 'northwest', '4922.9159'],
#  190: ['61', 'male', '31.57', '0', 'no', 'southeast', '12557.6053'],
#  191: ['36', 'female', '26.2', '0', 'no', 'southwest', '4883.866'],
#  192: ['25', 'male', '25.74', '0', 'no', 'southeast', '2137.6536'],
#  193: ['56', 'female', '26.6', '1', 'no', 'northwest', '12044.342'],
#  194: ['18', 'male', '34.43', '0', 'no', 'southeast', '1137.4697'],
#  195: ['19', 'male', '30.59', '0', 'no', 'northwest', '1639.5631'],
#  196: ['39', 'female', '32.8', '0', 'no', 'southwest', '5649.715'],
#  197: ['45', 'female', '28.6', '2', 'no', 'southeast', '8516.829'],
#  198: ['51', 'female', '18.05', '0', 'no', 'northwest', '9644.2525'],
#  199: ['64', 'female', '39.33', '0', 'no', 'northeast', '14901.5167'],
#  200: ['19', 'female', '32.11', '0', 'no', 'northwest', '2130.6759'],
#  201: ['48', 'female', '32.23', '1', 'no', 'southeast', '8871.1517'],
#  202: ['60', 'female', '24.035', '0', 'no', 'northwest', '13012.20865'],
#  203: ['27', 'female', '36.08', '0', 'yes', 'southeast', '37133.8982'],
#  204: ['46', 'male', '22.3', '0', 'no', 'southwest', '7147.105'],
#  205: ['28', 'female', '28.88', '1', 'no', 'northeast', '4337.7352'],
#  206: ['59', 'male', '26.4', '0', 'no', 'southeast', '11743.299'],
#  207: ['35', 'male', '27.74', '2', 'yes', 'northeast', '20984.0936'],
#  208: ['63', 'female', '31.8', '0', 'no', 'southwest', '13880.949'],
#  209: ['40', 'male', '41.23', '1', 'no', 'northeast', '6610.1097'],
#  210: ['20', 'male', '33', '1', 'no', 'southwest', '1980.07'],
#  211: ['40', 'male', '30.875', '4', 'no', 'northwest', '8162.71625'],
#  212: ['24', 'male', '28.5', '2', 'no', 'northwest', '3537.703'],
#  213: ['34', 'female', '26.73', '1', 'no', 'southeast', '5002.7827'],
#  214: ['45', 'female', '30.9', '2', 'no', 'southwest', '8520.026'],
#  215: ['41', 'female', '37.1', '2', 'no', 'southwest', '7371.772'],
#  216: ['53', 'female', '26.6', '0', 'no', 'northwest', '10355.641'],
#  217: ['27', 'male', '23.1', '0', 'no', 'southeast', '2483.736'],
#  218: ['26', 'female', '29.92', '1', 'no', 'southeast', '3392.9768'],
#  219: ['24', 'female', '23.21', '0', 'no', 'southeast', '25081.76784'],
#  220: ['34', 'female', '33.7', '1', 'no', 'southwest', '5012.471'],
#  221: ['53', 'female', '33.25', '0', 'no', 'northeast', '10564.8845'],
#  222: ['32', 'male', '30.8', '3', 'no', 'southwest', '5253.524'],
#  223: ['19', 'male', '34.8', '0', 'yes', 'southwest', '34779.615'],
#  224: ['42', 'male', '24.64', '0', 'yes', 'southeast', '19515.5416'],
#  225: ['55', 'male', '33.88', '3', 'no', 'southeast', '11987.1682'],
#  226: ['28', 'male', '38.06', '0', 'no', 'southeast', '2689.4954'],
#  227: ['58', 'female', '41.91', '0', 'no', 'southeast', '24227.33724'],
#  228: ['41', 'female', '31.635', '1', 'no', 'northeast', '7358.17565'],
#  229: ['47', 'male', '25.46', '2', 'no', 'northeast', '9225.2564'],
#  230: ['42', 'female', '36.195', '1', 'no', 'northwest', '7443.64305'],
#  231: ['59', 'female', '27.83', '3', 'no', 'southeast', '14001.2867'],
#  232: ['19', 'female', '17.8', '0', 'no', 'southwest', '1727.785'],
#  233: ['59', 'male', '27.5', '1', 'no', 'southwest', '12333.828'],
#  234: ['39', 'male', '24.51', '2', 'no', 'northwest', '6710.1919'],
#  235: ['40', 'female', '22.22', '2', 'yes', 'southeast', '19444.2658'],
#  236: ['18', 'female', '26.73', '0', 'no', 'southeast', '1615.7667'],
#  237: ['31', 'male', '38.39', '2', 'no', 'southeast', '4463.2051'],
#  238: ['19', 'male', '29.07', '0', 'yes', 'northwest', '17352.6803'],
#  239: ['44', 'male', '38.06', '1', 'no', 'southeast', '7152.6714'],
#  240: ['23', 'female', '36.67', '2', 'yes', 'northeast', '38511.6283'],
#  241: ['33', 'female', '22.135', '1', 'no', 'northeast', '5354.07465'],
#  242: ['55', 'female', '26.8', '1', 'no', 'southwest', '35160.13457'],
#  243: ['40', 'male', '35.3', '3', 'no', 'southwest', '7196.867'],
#  244: ['63', 'female', '27.74', '0', 'yes', 'northeast', '29523.1656'],
#  245: ['54', 'male', '30.02', '0', 'no', 'northwest', '24476.47851'],
#  246: ['60', 'female', '38.06', '0', 'no', 'southeast', '12648.7034'],
#  247: ['24', 'male', '35.86', '0', 'no', 'southeast', '1986.9334'],
#  248: ['19', 'male', '20.9', '1', 'no', 'southwest', '1832.094'],
#  249: ['29', 'male', '28.975', '1', 'no', 'northeast', '4040.55825'],
#  250: ['18', 'male', '17.29', '2', 'yes', 'northeast', '12829.4551'],
#  251: ['63', 'female', '32.2', '2', 'yes', 'southwest', '47305.305'],
#  252: ['54', 'male', '34.21', '2', 'yes', 'southeast', '44260.7499'],
#  253: ['27', 'male', '30.3', '3', 'no', 'southwest', '4260.744'],
#  254: ['50', 'male', '31.825', '0', 'yes', 'northeast', '41097.16175'],
#  255: ['55', 'female', '25.365', '3', 'no', 'northeast', '13047.33235'],
#  256: ['56', 'male', '33.63', '0', 'yes', 'northwest', '43921.1837'],
#  257: ['38', 'female', '40.15', '0', 'no', 'southeast', '5400.9805'],
#  258: ['51', 'male', '24.415', '4', 'no', 'northwest', '11520.09985'],
#  259: ['19', 'male', '31.92', '0', 'yes', 'northwest', '33750.2918'],
#  260: ['58', 'female', '25.2', '0', 'no', 'southwest', '11837.16'],
#  261: ['20', 'female', '26.84', '1', 'yes', 'southeast', '17085.2676'],
#  262: ['52', 'male', '24.32', '3', 'yes', 'northeast', '24869.8368'],
#  263: ['19', 'male', '36.955', '0', 'yes', 'northwest', '36219.40545'],
#  264: ['53', 'female', '38.06', '3', 'no', 'southeast', '20462.99766'],
#  265: ['46', 'male', '42.35', '3', 'yes', 'southeast', '46151.1245'],
#  266: ['40', 'male', '19.8', '1', 'yes', 'southeast', '17179.522'],
#  267: ['59', 'female', '32.395', '3', 'no', 'northeast', '14590.63205'],
#  268: ['45', 'male', '30.2', '1', 'no', 'southwest', '7441.053'],
#  269: ['49', 'male', '25.84', '1', 'no', 'northeast', '9282.4806'],
#  270: ['18', 'male', '29.37', '1', 'no', 'southeast', '1719.4363'],
#  271: ['50', 'male', '34.2', '2', 'yes', 'southwest', '42856.838'],
#  272: ['41', 'male', '37.05', '2', 'no', 'northwest', '7265.7025'],
#  273: ['50', 'male', '27.455', '1', 'no', 'northeast', '9617.66245'],
#  274: ['25', 'male', '27.55', '0', 'no', 'northwest', '2523.1695'],
#  275: ['47', 'female', '26.6', '2', 'no', 'northeast', '9715.841'],
#  276: ['19', 'male', '20.615', '2', 'no', 'northwest', '2803.69785'],
#  277: ['22', 'female', '24.3', '0', 'no', 'southwest', '2150.469'],
#  278: ['59', 'male', '31.79', '2', 'no', 'southeast', '12928.7911'],
#  279: ['51', 'female', '21.56', '1', 'no', 'southeast', '9855.1314'],
#  280: ['40', 'female', '28.12', '1', 'yes', 'northeast', '22331.5668'],
#  281: ['54', 'male', '40.565', '3', 'yes', 'northeast', '48549.17835'],
#  282: ['30', 'male', '27.645', '1', 'no', 'northeast', '4237.12655'],
#  283: ['55', 'female', '32.395', '1', 'no', 'northeast', '11879.10405'],
#  284: ['52', 'female', '31.2', '0', 'no', 'southwest', '9625.92'],
#  285: ['46', 'male', '26.62', '1', 'no', 'southeast', '7742.1098'],
#  286: ['46', 'female', '48.07', '2', 'no', 'northeast', '9432.9253'],
#  287: ['63', 'female', '26.22', '0', 'no', 'northwest', '14256.1928'],
#  288: ['59', 'female', '36.765', '1', 'yes', 'northeast', '47896.79135'],
#  289: ['52', 'male', '26.4', '3', 'no', 'southeast', '25992.82104'],
#  290: ['28', 'female', '33.4', '0', 'no', 'southwest', '3172.018'],
#  291: ['29', 'male', '29.64', '1', 'no', 'northeast', '20277.80751'],
#  292: ['25', 'male', '45.54', '2', 'yes', 'southeast', '42112.2356'],
#  293: ['22', 'female', '28.82', '0', 'no', 'southeast', '2156.7518'],
#  294: ['25', 'male', '26.8', '3', 'no', 'southwest', '3906.127'],
#  295: ['18', 'male', '22.99', '0', 'no', 'northeast', '1704.5681'],
#  296: ['19', 'male', '27.7', '0', 'yes', 'southwest', '16297.846'],
#  297: ['47', 'male', '25.41', '1', 'yes', 'southeast', '21978.6769'],
#  298: ['31', 'male', '34.39', '3', 'yes', 'northwest', '38746.3551'],
#  299: ['48', 'female', '28.88', '1', 'no', 'northwest', '9249.4952'],
#  300: ['36', 'male', '27.55', '3', 'no', 'northeast', '6746.7425'],
#  301: ['53', 'female', '22.61', '3', 'yes', 'northeast', '24873.3849'],
#  302: ['56', 'female', '37.51', '2', 'no', 'southeast', '12265.5069'],
#  303: ['28', 'female', '33', '2', 'no', 'southeast', '4349.462'],
#  304: ['57', 'female', '38', '2', 'no', 'southwest', '12646.207'],
#  305: ['29', 'male', '33.345', '2', 'no', 'northwest', '19442.3535'],
#  306: ['28', 'female', '27.5', '2', 'no', 'southwest', '20177.67113'],
#  307: ['30', 'female', '33.33', '1', 'no', 'southeast', '4151.0287'],
#  308: ['58', 'male', '34.865', '0', 'no', 'northeast', '11944.59435'],
#  309: ['41', 'female', '33.06', '2', 'no', 'northwest', '7749.1564'],
#  310: ['50', 'male', '26.6', '0', 'no', 'southwest', '8444.474'],
#  311: ['19', 'female', '24.7', '0', 'no', 'southwest', '1737.376'],
#  312: ['43', 'male', '35.97', '3', 'yes', 'southeast', '42124.5153'],
#  313: ['49', 'male', '35.86', '0', 'no', 'southeast', '8124.4084'],
#  314: ['27', 'female', '31.4', '0', 'yes', 'southwest', '34838.873'],
#  315: ['52', 'male', '33.25', '0', 'no', 'northeast', '9722.7695'],
#  316: ['50', 'male', '32.205', '0', 'no', 'northwest', '8835.26495'],
#  317: ['54', 'male', '32.775', '0', 'no', 'northeast', '10435.06525'],
#  318: ['44', 'female', '27.645', '0', 'no', 'northwest', '7421.19455'],
#  319: ['32', 'male', '37.335', '1', 'no', 'northeast', '4667.60765'],
#  320: ['34', 'male', '25.27', '1', 'no', 'northwest', '4894.7533'],
#  321: ['26', 'female', '29.64', '4', 'no', 'northeast', '24671.66334'],
#  322: ['34', 'male', '30.8', '0', 'yes', 'southwest', '35491.64'],
#  323: ['57', 'male', '40.945', '0', 'no', 'northeast', '11566.30055'],
#  324: ['29', 'male', '27.2', '0', 'no', 'southwest', '2866.091'],
#  325: ['40', 'male', '34.105', '1', 'no', 'northeast', '6600.20595'],
#  326: ['27', 'female', '23.21', '1', 'no', 'southeast', '3561.8889'],
#  327: ['45', 'male', '36.48', '2', 'yes', 'northwest', '42760.5022'],
#  328: ['64', 'female', '33.8', '1', 'yes', 'southwest', '47928.03'],
#  329: ['52', 'male', '36.7', '0', 'no', 'southwest', '9144.565'],
#  330: ['61', 'female', '36.385', '1', 'yes', 'northeast', '48517.56315'],
#  331: ['52', 'male', '27.36', '0', 'yes', 'northwest', '24393.6224'],
#  332: ['61', 'female', '31.16', '0', 'no', 'northwest', '13429.0354'],
#  333: ['56', 'female', '28.785', '0', 'no', 'northeast', '11658.37915'],
#  334: ['43', 'female', '35.72', '2', 'no', 'northeast', '19144.57652'],
#  335: ['64', 'male', '34.5', '0', 'no', 'southwest', '13822.803'],
#  336: ['60', 'male', '25.74', '0', 'no', 'southeast', '12142.5786'],
#  337: ['62', 'male', '27.55', '1', 'no', 'northwest', '13937.6665'],
#  338: ['50', 'male', '32.3', '1', 'yes', 'northeast', '41919.097'],
#  339: ['46', 'female', '27.72', '1', 'no', 'southeast', '8232.6388'],
#  340: ['24', 'female', '27.6', '0', 'no', 'southwest', '18955.22017'],
#  341: ['62', 'male', '30.02', '0', 'no', 'northwest', '13352.0998'],
#  342: ['60', 'female', '27.55', '0', 'no', 'northeast', '13217.0945'],
#  343: ['63', 'male', '36.765', '0', 'no', 'northeast', '13981.85035'],
#  344: ['49', 'female', '41.47', '4', 'no', 'southeast', '10977.2063'],
#  345: ['34', 'female', '29.26', '3', 'no', 'southeast', '6184.2994'],
#  346: ['33', 'male', '35.75', '2', 'no', 'southeast', '4889.9995'],
#  347: ['46', 'male', '33.345', '1', 'no', 'northeast', '8334.45755'],
#  348: ['36', 'female', '29.92', '1', 'no', 'southeast', '5478.0368'],
#  349: ['19', 'male', '27.835', '0', 'no', 'northwest', '1635.73365'],
#  350: ['57', 'female', '23.18', '0', 'no', 'northwest', '11830.6072'],
#  351: ['50', 'female', '25.6', '0', 'no', 'southwest', '8932.084'],
#  352: ['30', 'female', '27.7', '0', 'no', 'southwest', '3554.203'],
#  353: ['33', 'male', '35.245', '0', 'no', 'northeast', '12404.8791'],
#  354: ['18', 'female', '38.28', '0', 'no', 'southeast', '14133.03775'],
#  355: ['46', 'male', '27.6', '0', 'no', 'southwest', '24603.04837'],
#  356: ['46', 'male', '43.89', '3', 'no', 'southeast', '8944.1151'],
#  357: ['47', 'male', '29.83', '3', 'no', 'northwest', '9620.3307'],
#  358: ['23', 'male', '41.91', '0', 'no', 'southeast', '1837.2819'],
#  359: ['18', 'female', '20.79', '0', 'no', 'southeast', '1607.5101'],
#  360: ['48', 'female', '32.3', '2', 'no', 'northeast', '10043.249'],
#  361: ['35', 'male', '30.5', '1', 'no', 'southwest', '4751.07'],
#  362: ['19', 'female', '21.7', '0', 'yes', 'southwest', '13844.506'],
#  363: ['21', 'female', '26.4', '1', 'no', 'southwest', '2597.779'],
#  364: ['21', 'female', '21.89', '2', 'no', 'southeast', '3180.5101'],
#  365: ['49', 'female', '30.78', '1', 'no', 'northeast', '9778.3472'],
#  366: ['56', 'female', '32.3', '3', 'no', 'northeast', '13430.265'],
#  367: ['42', 'female', '24.985', '2', 'no', 'northwest', '8017.06115'],
#  368: ['44', 'male', '32.015', '2', 'no', 'northwest', '8116.26885'],
#  369: ['18', 'male', '30.4', '3', 'no', 'northeast', '3481.868'],
#  370: ['61', 'female', '21.09', '0', 'no', 'northwest', '13415.0381'],
#  371: ['57', 'female', '22.23', '0', 'no', 'northeast', '12029.2867'],
#  372: ['42', 'female', '33.155', '1', 'no', 'northeast', '7639.41745'],
#  373: ['26', 'male', '32.9', '2', 'yes', 'southwest', '36085.219'],
#  374: ['20', 'male', '33.33', '0', 'no', 'southeast', '1391.5287'],
#  375: ['23', 'female', '28.31', '0', 'yes', 'northwest', '18033.9679'],
#  376: ['39', 'female', '24.89', '3', 'yes', 'northeast', '21659.9301'],
#  377: ['24', 'male', '40.15', '0', 'yes', 'southeast', '38126.2465'],
#  378: ['64', 'female', '30.115', '3', 'no', 'northwest', '16455.70785'],
#  379: ['62', 'male', '31.46', '1', 'no', 'southeast', '27000.98473'],
#  380: ['27', 'female', '17.955', '2', 'yes', 'northeast', '15006.57945'],
#  381: ['55', 'male', '30.685', '0', 'yes', 'northeast', '42303.69215'],
#  382: ['55', 'male', '33', '0', 'no', 'southeast', '20781.48892'],
#  383: ['35', 'female', '43.34', '2', 'no', 'southeast', '5846.9176'],
#  384: ['44', 'male', '22.135', '2', 'no', 'northeast', '8302.53565'],
#  385: ['19', 'male', '34.4', '0', 'no', 'southwest', '1261.859'],
#  386: ['58', 'female', '39.05', '0', 'no', 'southeast', '11856.4115'],
#  387: ['50', 'male', '25.365', '2', 'no', 'northwest', '30284.64294'],
#  388: ['26', 'female', '22.61', '0', 'no', 'northwest', '3176.8159'],
#  389: ['24', 'female', '30.21', '3', 'no', 'northwest', '4618.0799'],
#  390: ['48', 'male', '35.625', '4', 'no', 'northeast', '10736.87075'],
#  391: ['19', 'female', '37.43', '0', 'no', 'northwest', '2138.0707'],
#  392: ['48', 'male', '31.445', '1', 'no', 'northeast', '8964.06055'],
#  393: ['49', 'male', '31.35', '1', 'no', 'northeast', '9290.1395'],
#  394: ['46', 'female', '32.3', '2', 'no', 'northeast', '9411.005'],
#  395: ['46', 'male', '19.855', '0', 'no', 'northwest', '7526.70645'],
#  396: ['43', 'female', '34.4', '3', 'no', 'southwest', '8522.003'],
#  397: ['21', 'male', '31.02', '0', 'no', 'southeast', '16586.49771'],
#  398: ['64', 'male', '25.6', '2', 'no', 'southwest', '14988.432'],
#  399: ['18', 'female', '38.17', '0', 'no', 'southeast', '1631.6683'],
#  400: ['51', 'female', '20.6', '0', 'no', 'southwest', '9264.797'],
#  401: ['47', 'male', '47.52', '1', 'no', 'southeast', '8083.9198'],
#  402: ['64', 'female', '32.965', '0', 'no', 'northwest', '14692.66935'],
#  403: ['49', 'male', '32.3', '3', 'no', 'northwest', '10269.46'],
#  404: ['31', 'male', '20.4', '0', 'no', 'southwest', '3260.199'],
#  405: ['52', 'female', '38.38', '2', 'no', 'northeast', '11396.9002'],
#  406: ['33', 'female', '24.31', '0', 'no', 'southeast', '4185.0979'],
#  407: ['47', 'female', '23.6', '1', 'no', 'southwest', '8539.671'],
#  408: ['38', 'male', '21.12', '3', 'no', 'southeast', '6652.5288'],
#  409: ['32', 'male', '30.03', '1', 'no', 'southeast', '4074.4537'],
#  410: ['19', 'male', '17.48', '0', 'no', 'northwest', '1621.3402'],
#  411: ['44', 'female', '20.235', '1', 'yes', 'northeast', '19594.80965'],
#  412: ['26', 'female', '17.195', '2', 'yes', 'northeast', '14455.64405'],
#  413: ['25', 'male', '23.9', '5', 'no', 'southwest', '5080.096'],
#  414: ['19', 'female', '35.15', '0', 'no', 'northwest', '2134.9015'],
#  415: ['43', 'female', '35.64', '1', 'no', 'southeast', '7345.7266'],
#  416: ['52', 'male', '34.1', '0', 'no', 'southeast', '9140.951'],
#  417: ['36', 'female', '22.6', '2', 'yes', 'southwest', '18608.262'],
#  418: ['64', 'male', '39.16', '1', 'no', 'southeast', '14418.2804'],
#  419: ['63', 'female', '26.98', '0', 'yes', 'northwest', '28950.4692'],
#  420: ['64', 'male', '33.88', '0', 'yes', 'southeast', '46889.2612'],
#  421: ['61', 'male', '35.86', '0', 'yes', 'southeast', '46599.1084'],
#  422: ['40', 'male', '32.775', '1', 'yes', 'northeast', '39125.33225'],
#  423: ['25', 'male', '30.59', '0', 'no', 'northeast', '2727.3951'],
#  424: ['48', 'male', '30.2', '2', 'no', 'southwest', '8968.33'],
#  425: ['45', 'male', '24.31', '5', 'no', 'southeast', '9788.8659'],
#  426: ['38', 'female', '27.265', '1', 'no', 'northeast', '6555.07035'],
#  427: ['18', 'female', '29.165', '0', 'no', 'northeast', '7323.734819'],
#  428: ['21', 'female', '16.815', '1', 'no', 'northeast', '3167.45585'],
#  429: ['27', 'female', '30.4', '3', 'no', 'northwest', '18804.7524'],
#  430: ['19', 'male', '33.1', '0', 'no', 'southwest', '23082.95533'],
#  431: ['29', 'female', '20.235', '2', 'no', 'northwest', '4906.40965'],
#  432: ['42', 'male', '26.9', '0', 'no', 'southwest', '5969.723'],
#  433: ['60', 'female', '30.5', '0', 'no', 'southwest', '12638.195'],
#  434: ['31', 'male', '28.595', '1', 'no', 'northwest', '4243.59005'],
#  435: ['60', 'male', '33.11', '3', 'no', 'southeast', '13919.8229'],
#  436: ['22', 'male', '31.73', '0', 'no', 'northeast', '2254.7967'],
#  437: ['35', 'male', '28.9', '3', 'no', 'southwest', '5926.846'],
#  438: ['52', 'female', '46.75', '5', 'no', 'southeast', '12592.5345'],
#  439: ['26', 'male', '29.45', '0', 'no', 'northeast', '2897.3235'],
#  440: ['31', 'female', '32.68', '1', 'no', 'northwest', '4738.2682'],
#  441: ['33', 'female', '33.5', '0', 'yes', 'southwest', '37079.372'],
#  442: ['18', 'male', '43.01', '0', 'no', 'southeast', '1149.3959'],
#  443: ['59', 'female', '36.52', '1', 'no', 'southeast', '28287.89766'],
#  444: ['56', 'male', '26.695', '1', 'yes', 'northwest', '26109.32905'],
#  445: ['45', 'female', '33.1', '0', 'no', 'southwest', '7345.084'],
#  446: ['60', 'male', '29.64', '0', 'no', 'northeast', '12730.9996'],
#  447: ['56', 'female', '25.65', '0', 'no', 'northwest', '11454.0215'],
#  448: ['40', 'female', '29.6', '0', 'no', 'southwest', '5910.944'],
#  449: ['35', 'male', '38.6', '1', 'no', 'southwest', '4762.329'],
#  450: ['39', 'male', '29.6', '4', 'no', 'southwest', '7512.267'],
#  451: ['30', 'male', '24.13', '1', 'no', 'northwest', '4032.2407'],
#  452: ['24', 'male', '23.4', '0', 'no', 'southwest', '1969.614'],
#  453: ['20', 'male', '29.735', '0', 'no', 'northwest', '1769.53165'],
#  454: ['32', 'male', '46.53', '2', 'no', 'southeast', '4686.3887'],
#  455: ['59', 'male', '37.4', '0', 'no', 'southwest', '21797.0004'],
#  456: ['55', 'female', '30.14', '2', 'no', 'southeast', '11881.9696'],
#  457: ['57', 'female', '30.495', '0', 'no', 'northwest', '11840.77505'],
#  458: ['56', 'male', '39.6', '0', 'no', 'southwest', '10601.412'],
#  459: ['40', 'female', '33', '3', 'no', 'southeast', '7682.67'],
#  460: ['49', 'female', '36.63', '3', 'no', 'southeast', '10381.4787'],
#  461: ['42', 'male', '30', '0', 'yes', 'southwest', '22144.032'],
#  462: ['62', 'female', '38.095', '2', 'no', 'northeast', '15230.32405'],
#  463: ['56', 'male', '25.935', '0', 'no', 'northeast', '11165.41765'],
#  464: ['19', 'male', '25.175', '0', 'no', 'northwest', '1632.03625'],
#  465: ['30', 'female', '28.38', '1', 'yes', 'southeast', '19521.9682'],
#  466: ['60', 'female', '28.7', '1', 'no', 'southwest', '13224.693'],
#  467: ['56', 'female', '33.82', '2', 'no', 'northwest', '12643.3778'],
#  468: ['28', 'female', '24.32', '1', 'no', 'northeast', '23288.9284'],
#  469: ['18', 'female', '24.09', '1', 'no', 'southeast', '2201.0971'],
#  470: ['27', 'male', '32.67', '0', 'no', 'southeast', '2497.0383'],
#  471: ['18', 'female', '30.115', '0', 'no', 'northeast', '2203.47185'],
#  472: ['19', 'female', '29.8', '0', 'no', 'southwest', '1744.465'],
#  473: ['47', 'female', '33.345', '0', 'no', 'northeast', '20878.78443'],
#  474: ['54', 'male', '25.1', '3', 'yes', 'southwest', '25382.297'],
#  475: ['61', 'male', '28.31', '1', 'yes', 'northwest', '28868.6639'],
#  476: ['24', 'male', '28.5', '0', 'yes', 'northeast', '35147.52848'],
#  477: ['25', 'male', '35.625', '0', 'no', 'northwest', '2534.39375'],
#  478: ['21', 'male', '36.85', '0', 'no', 'southeast', '1534.3045'],
#  479: ['23', 'male', '32.56', '0', 'no', 'southeast', '1824.2854'],
#  480: ['63', 'male', '41.325', '3', 'no', 'northwest', '15555.18875'],
#  481: ['49', 'male', '37.51', '2', 'no', 'southeast', '9304.7019'],
#  482: ['18', 'female', '31.35', '0', 'no', 'southeast', '1622.1885'],
#  483: ['51', 'female', '39.5', '1', 'no', 'southwest', '9880.068'],
#  484: ['48', 'male', '34.3', '3', 'no', 'southwest', '9563.029'],
#  485: ['31', 'female', '31.065', '0', 'no', 'northeast', '4347.02335'],
#  486: ['54', 'female', '21.47', '3', 'no', 'northwest', '12475.3513'],
#  487: ['19', 'male', '28.7', '0', 'no', 'southwest', '1253.936'],
#  488: ['44', 'female', '38.06', '0', 'yes', 'southeast', '48885.13561'],
#  489: ['53', 'male', '31.16', '1', 'no', 'northwest', '10461.9794'],
#  490: ['19', 'female', '32.9', '0', 'no', 'southwest', '1748.774'],
#  491: ['61', 'female', '25.08', '0', 'no', 'southeast', '24513.09126'],
#  492: ['18', 'female', '25.08', '0', 'no', 'northeast', '2196.4732'],
#  493: ['61', 'male', '43.4', '0', 'no', 'southwest', '12574.049'],
#  494: ['21', 'male', '25.7', '4', 'yes', 'southwest', '17942.106'],
#  495: ['20', 'male', '27.93', '0', 'no', 'northeast', '1967.0227'],
#  496: ['31', 'female', '23.6', '2', 'no', 'southwest', '4931.647'],
#  497: ['45', 'male', '28.7', '2', 'no', 'southwest', '8027.968'],
#  498: ['44', 'female', '23.98', '2', 'no', 'southeast', '8211.1002'],
#  499: ['62', 'female', '39.2', '0', 'no', 'southwest', '13470.86'],
#  500: ['29', 'male', '34.4', '0', 'yes', 'southwest', '36197.699'],
#  501: ['43', 'male', '26.03', '0', 'no', 'northeast', '6837.3687'],
#  502: ['51', 'male', '23.21', '1', 'yes', 'southeast', '22218.1149'],
#  503: ['19', 'male', '30.25', '0', 'yes', 'southeast', '32548.3405'],
#  504: ['38', 'female', '28.93', '1', 'no', 'southeast', '5974.3847'],
#  505: ['37', 'male', '30.875', '3', 'no', 'northwest', '6796.86325'],
#  506: ['22', 'male', '31.35', '1', 'no', 'northwest', '2643.2685'],
#  507: ['21', 'male', '23.75', '2', 'no', 'northwest', '3077.0955'],
#  508: ['24', 'female', '25.27', '0', 'no', 'northeast', '3044.2133'],
#  509: ['57', 'female', '28.7', '0', 'no', 'southwest', '11455.28'],
#  510: ['56', 'male', '32.11', '1', 'no', 'northeast', '11763.0009'],
#  511: ['27', 'male', '33.66', '0', 'no', 'southeast', '2498.4144'],
#  512: ['51', 'male', '22.42', '0', 'no', 'northeast', '9361.3268'],
#  513: ['19', 'male', '30.4', '0', 'no', 'southwest', '1256.299'],
#  514: ['39', 'male', '28.3', '1', 'yes', 'southwest', '21082.16'],
#  515: ['58', 'male', '35.7', '0', 'no', 'southwest', '11362.755'],
#  516: ['20', 'male', '35.31', '1', 'no', 'southeast', '27724.28875'],
#  517: ['45', 'male', '30.495', '2', 'no', 'northwest', '8413.46305'],
#  518: ['35', 'female', '31', '1', 'no', 'southwest', '5240.765'],
#  519: ['31', 'male', '30.875', '0', 'no', 'northeast', '3857.75925'],
#  520: ['50', 'female', '27.36', '0', 'no', 'northeast', '25656.57526'],
#  521: ['32', 'female', '44.22', '0', 'no', 'southeast', '3994.1778'],
#  522: ['51', 'female', '33.915', '0', 'no', 'northeast', '9866.30485'],
#  523: ['38', 'female', '37.73', '0', 'no', 'southeast', '5397.6167'],
#  524: ['42', 'male', '26.07', '1', 'yes', 'southeast', '38245.59327'],
#  525: ['18', 'female', '33.88', '0', 'no', 'southeast', '11482.63485'],
#  526: ['19', 'female', '30.59', '2', 'no', 'northwest', '24059.68019'],
#  527: ['51', 'female', '25.8', '1', 'no', 'southwest', '9861.025'],
#  528: ['46', 'male', '39.425', '1', 'no', 'northeast', '8342.90875'],
#  529: ['18', 'male', '25.46', '0', 'no', 'northeast', '1708.0014'],
#  530: ['57', 'male', '42.13', '1', 'yes', 'southeast', '48675.5177'],
#  531: ['62', 'female', '31.73', '0', 'no', 'northeast', '14043.4767'],
#  532: ['59', 'male', '29.7', '2', 'no', 'southeast', '12925.886'],
#  533: ['37', 'male', '36.19', '0', 'no', 'southeast', '19214.70553'],
#  534: ['64', 'male', '40.48', '0', 'no', 'southeast', '13831.1152'],
#  535: ['38', 'male', '28.025', '1', 'no', 'northeast', '6067.12675'],
#  536: ['33', 'female', '38.9', '3', 'no', 'southwest', '5972.378'],
#  537: ['46', 'female', '30.2', '2', 'no', 'southwest', '8825.086'],
#  538: ['46', 'female', '28.05', '1', 'no', 'southeast', '8233.0975'],
#  539: ['53', 'male', '31.35', '0', 'no', 'southeast', '27346.04207'],
#  540: ['34', 'female', '38', '3', 'no', 'southwest', '6196.448'],
#  541: ['20', 'female', '31.79', '2', 'no', 'southeast', '3056.3881'],
#  542: ['63', 'female', '36.3', '0', 'no', 'southeast', '13887.204'],
#  543: ['54', 'female', '47.41', '0', 'yes', 'southeast', '63770.42801'],
#  544: ['54', 'male', '30.21', '0', 'no', 'northwest', '10231.4999'],
#  545: ['49', 'male', '25.84', '2', 'yes', 'northwest', '23807.2406'],
#  546: ['28', 'male', '35.435', '0', 'no', 'northeast', '3268.84665'],
#  547: ['54', 'female', '46.7', '2', 'no', 'southwest', '11538.421'],
#  548: ['25', 'female', '28.595', '0', 'no', 'northeast', '3213.62205'],
#  549: ['43', 'female', '46.2', '0', 'yes', 'southeast', '45863.205'],
#  550: ['63', 'male', '30.8', '0', 'no', 'southwest', '13390.559'],
#  551: ['32', 'female', '28.93', '0', 'no', 'southeast', '3972.9247'],
#  552: ['62', 'male', '21.4', '0', 'no', 'southwest', '12957.118'],
#  553: ['52', 'female', '31.73', '2', 'no', 'northwest', '11187.6567'],
#  554: ['25', 'female', '41.325', '0', 'no', 'northeast', '17878.90068'],
#  555: ['28', 'male', '23.8', '2', 'no', 'southwest', '3847.674'],
#  556: ['46', 'male', '33.44', '1', 'no', 'northeast', '8334.5896'],
#  557: ['34', 'male', '34.21', '0', 'no', 'southeast', '3935.1799'],
#  558: ['35', 'female', '34.105', '3', 'yes', 'northwest', '39983.42595'],
#  559: ['19', 'male', '35.53', '0', 'no', 'northwest', '1646.4297'],
#  560: ['46', 'female', '19.95', '2', 'no', 'northwest', '9193.8385'],
#  561: ['54', 'female', '32.68', '0', 'no', 'northeast', '10923.9332'],
#  562: ['27', 'male', '30.5', '0', 'no', 'southwest', '2494.022'],
#  563: ['50', 'male', '44.77', '1', 'no', 'southeast', '9058.7303'],
#  564: ['18', 'female', '32.12', '2', 'no', 'southeast', '2801.2588'],
#  565: ['19', 'female', '30.495', '0', 'no', 'northwest', '2128.43105'],
#  566: ['38', 'female', '40.565', '1', 'no', 'northwest', '6373.55735'],
#  567: ['41', 'male', '30.59', '2', 'no', 'northwest', '7256.7231'],
#  568: ['49', 'female', '31.9', '5', 'no', 'southwest', '11552.904'],
#  569: ['48', 'male', '40.565', '2', 'yes', 'northwest', '45702.02235'],
#  570: ['31', 'female', '29.1', '0', 'no', 'southwest', '3761.292'],
#  571: ['18', 'female', '37.29', '1', 'no', 'southeast', '2219.4451'],
#  572: ['30', 'female', '43.12', '2', 'no', 'southeast', '4753.6368'],
#  573: ['62', 'female', '36.86', '1', 'no', 'northeast', '31620.00106'],
#  574: ['57', 'female', '34.295', '2', 'no', 'northeast', '13224.05705'],
#  575: ['58', 'female', '27.17', '0', 'no', 'northwest', '12222.8983'],
#  576: ['22', 'male', '26.84', '0', 'no', 'southeast', '1664.9996'],
#  577: ['31', 'female', '38.095', '1', 'yes', 'northeast', '58571.07448'],
#  578: ['52', 'male', '30.2', '1', 'no', 'southwest', '9724.53'],
#  579: ['25', 'female', '23.465', '0', 'no', 'northeast', '3206.49135'],
#  580: ['59', 'male', '25.46', '1', 'no', 'northeast', '12913.9924'],
#  581: ['19', 'male', '30.59', '0', 'no', 'northwest', '1639.5631'],
#  582: ['39', 'male', '45.43', '2', 'no', 'southeast', '6356.2707'],
#  583: ['32', 'female', '23.65', '1', 'no', 'southeast', '17626.23951'],
#  584: ['19', 'male', '20.7', '0', 'no', 'southwest', '1242.816'],
#  585: ['33', 'female', '28.27', '1', 'no', 'southeast', '4779.6023'],
#  586: ['21', 'male', '20.235', '3', 'no', 'northeast', '3861.20965'],
#  587: ['34', 'female', '30.21', '1', 'yes', 'northwest', '43943.8761'],
#  588: ['61', 'female', '35.91', '0', 'no', 'northeast', '13635.6379'],
#  589: ['38', 'female', '30.69', '1', 'no', 'southeast', '5976.8311'],
#  590: ['58', 'female', '29', '0', 'no', 'southwest', '11842.442'],
#  591: ['47', 'male', '19.57', '1', 'no', 'northwest', '8428.0693'],
#  592: ['20', 'male', '31.13', '2', 'no', 'southeast', '2566.4707'],
#  593: ['21', 'female', '21.85', '1', 'yes', 'northeast', '15359.1045'],
#  594: ['41', 'male', '40.26', '0', 'no', 'southeast', '5709.1644'],
#  595: ['46', 'female', '33.725', '1', 'no', 'northeast', '8823.98575'],
#  596: ['42', 'female', '29.48', '2', 'no', 'southeast', '7640.3092'],
#  597: ['34', 'female', '33.25', '1', 'no', 'northeast', '5594.8455'],
#  598: ['43', 'male', '32.6', '2', 'no', 'southwest', '7441.501'],
#  599: ['52', 'female', '37.525', '2', 'no', 'northwest', '33471.97189'],
#  600: ['18', 'female', '39.16', '0', 'no', 'southeast', '1633.0444'],
#  601: ['51', 'male', '31.635', '0', 'no', 'northwest', '9174.13565'],
#  602: ['56', 'female', '25.3', '0', 'no', 'southwest', '11070.535'],
#  603: ['64', 'female', '39.05', '3', 'no', 'southeast', '16085.1275'],
#  604: ['19', 'female', '28.31', '0', 'yes', 'northwest', '17468.9839'],
#  605: ['51', 'female', '34.1', '0', 'no', 'southeast', '9283.562'],
#  606: ['27', 'female', '25.175', '0', 'no', 'northeast', '3558.62025'],
#  607: ['59', 'female', '23.655', '0', 'yes', 'northwest', '25678.77845'],
#  608: ['28', 'male', '26.98', '2', 'no', 'northeast', '4435.0942'],
#  609: ['30', 'male', '37.8', '2', 'yes', 'southwest', '39241.442'],
#  610: ['47', 'female', '29.37', '1', 'no', 'southeast', '8547.6913'],
#  611: ['38', 'female', '34.8', '2', 'no', 'southwest', '6571.544'],
#  612: ['18', 'female', '33.155', '0', 'no', 'northeast', '2207.69745'],
#  613: ['34', 'female', '19', '3', 'no', 'northeast', '6753.038'],
#  614: ['20', 'female', '33', '0', 'no', 'southeast', '1880.07'],
#  615: ['47', 'female', '36.63', '1', 'yes', 'southeast', '42969.8527'],
#  616: ['56', 'female', '28.595', '0', 'no', 'northeast', '11658.11505'],
#  617: ['49', 'male', '25.6', '2', 'yes', 'southwest', '23306.547'],
#  618: ['19', 'female', '33.11', '0', 'yes', 'southeast', '34439.8559'],
#  619: ['55', 'female', '37.1', '0', 'no', 'southwest', '10713.644'],
#  620: ['30', 'male', '31.4', '1', 'no', 'southwest', '3659.346'],
#  621: ['37', 'male', '34.1', '4', 'yes', 'southwest', '40182.246'],
#  622: ['49', 'female', '21.3', '1', 'no', 'southwest', '9182.17'],
#  623: ['18', 'male', '33.535', '0', 'yes', 'northeast', '34617.84065'],
#  624: ['59', 'male', '28.785', '0', 'no', 'northwest', '12129.61415'],
#  625: ['29', 'female', '26.03', '0', 'no', 'northwest', '3736.4647'],
#  626: ['36', 'male', '28.88', '3', 'no', 'northeast', '6748.5912'],
#  627: ['33', 'male', '42.46', '1', 'no', 'southeast', '11326.71487'],
#  628: ['58', 'male', '38', '0', 'no', 'southwest', '11365.952'],
#  629: ['44', 'female', '38.95', '0', 'yes', 'northwest', '42983.4585'],
#  630: ['53', 'male', '36.1', '1', 'no', 'southwest', '10085.846'],
#  631: ['24', 'male', '29.3', '0', 'no', 'southwest', '1977.815'],
#  632: ['29', 'female', '35.53', '0', 'no', 'southeast', '3366.6697'],
#  633: ['40', 'male', '22.705', '2', 'no', 'northeast', '7173.35995'],
#  634: ['51', 'male', '39.7', '1', 'no', 'southwest', '9391.346'],
#  635: ['64', 'male', '38.19', '0', 'no', 'northeast', '14410.9321'],
#  636: ['19', 'female', '24.51', '1', 'no', 'northwest', '2709.1119'],
#  637: ['35', 'female', '38.095', '2', 'no', 'northeast', '24915.04626'],
#  638: ['39', 'male', '26.41', '0', 'yes', 'northeast', '20149.3229'],
#  639: ['56', 'male', '33.66', '4', 'no', 'southeast', '12949.1554'],
#  640: ['33', 'male', '42.4', '5', 'no', 'southwest', '6666.243'],
#  641: ['42', 'male', '28.31', '3', 'yes', 'northwest', '32787.45859'],
#  642: ['61', 'male', '33.915', '0', 'no', 'northeast', '13143.86485'],
#  643: ['23', 'female', '34.96', '3', 'no', 'northwest', '4466.6214'],
#  644: ['43', 'male', '35.31', '2', 'no', 'southeast', '18806.14547'],
#  645: ['48', 'male', '30.78', '3', 'no', 'northeast', '10141.1362'],
#  646: ['39', 'male', '26.22', '1', 'no', 'northwest', '6123.5688'],
#  647: ['40', 'female', '23.37', '3', 'no', 'northeast', '8252.2843'],
#  648: ['18', 'male', '28.5', '0', 'no', 'northeast', '1712.227'],
#  649: ['58', 'female', '32.965', '0', 'no', 'northeast', '12430.95335'],
#  650: ['49', 'female', '42.68', '2', 'no', 'southeast', '9800.8882'],
#  651: ['53', 'female', '39.6', '1', 'no', 'southeast', '10579.711'],
#  652: ['48', 'female', '31.13', '0', 'no', 'southeast', '8280.6227'],
#  653: ['45', 'female', '36.3', '2', 'no', 'southeast', '8527.532'],
#  654: ['59', 'female', '35.2', '0', 'no', 'southeast', '12244.531'],
#  655: ['52', 'female', '25.3', '2', 'yes', 'southeast', '24667.419'],
#  656: ['26', 'female', '42.4', '1', 'no', 'southwest', '3410.324'],
#  657: ['27', 'male', '33.155', '2', 'no', 'northwest', '4058.71245'],
#  658: ['48', 'female', '35.91', '1', 'no', 'northeast', '26392.26029'],
#  659: ['57', 'female', '28.785', '4', 'no', 'northeast', '14394.39815'],
#  660: ['37', 'male', '46.53', '3', 'no', 'southeast', '6435.6237'],
#  661: ['57', 'female', '23.98', '1', 'no', 'southeast', '22192.43711'],
#  662: ['32', 'female', '31.54', '1', 'no', 'northeast', '5148.5526'],
#  663: ['18', 'male', '33.66', '0', 'no', 'southeast', '1136.3994'],
#  664: ['64', 'female', '22.99', '0', 'yes', 'southeast', '27037.9141'],
#  665: ['43', 'male', '38.06', '2', 'yes', 'southeast', '42560.4304'],
#  666: ['49', 'male', '28.7', '1', 'no', 'southwest', '8703.456'],
#  667: ['40', 'female', '32.775', '2', 'yes', 'northwest', '40003.33225'],
#  668: ['62', 'male', '32.015', '0', 'yes', 'northeast', '45710.20785'],
#  669: ['40', 'female', '29.81', '1', 'no', 'southeast', '6500.2359'],
#  670: ['30', 'male', '31.57', '3', 'no', 'southeast', '4837.5823'],
#  671: ['29', 'female', '31.16', '0', 'no', 'northeast', '3943.5954'],
#  672: ['36', 'male', '29.7', '0', 'no', 'southeast', '4399.731'],
#  673: ['41', 'female', '31.02', '0', 'no', 'southeast', '6185.3208'],
#  674: ['44', 'female', '43.89', '2', 'yes', 'southeast', '46200.9851'],
#  675: ['45', 'male', '21.375', '0', 'no', 'northwest', '7222.78625'],
#  676: ['55', 'female', '40.81', '3', 'no', 'southeast', '12485.8009'],
#  677: ['60', 'male', '31.35', '3', 'yes', 'northwest', '46130.5265'],
#  678: ['56', 'male', '36.1', '3', 'no', 'southwest', '12363.547'],
#  679: ['49', 'female', '23.18', '2', 'no', 'northwest', '10156.7832'],
#  680: ['21', 'female', '17.4', '1', 'no', 'southwest', '2585.269'],
#  681: ['19', 'male', '20.3', '0', 'no', 'southwest', '1242.26'],
#  682: ['39', 'male', '35.3', '2', 'yes', 'southwest', '40103.89'],
#  683: ['53', 'male', '24.32', '0', 'no', 'northwest', '9863.4718'],
#  684: ['33', 'female', '18.5', '1', 'no', 'southwest', '4766.022'],
#  685: ['53', 'male', '26.41', '2', 'no', 'northeast', '11244.3769'],
#  686: ['42', 'male', '26.125', '2', 'no', 'northeast', '7729.64575'],
#  687: ['40', 'male', '41.69', '0', 'no', 'southeast', '5438.7491'],
#  688: ['47', 'female', '24.1', '1', 'no', 'southwest', '26236.57997'],
#  689: ['27', 'male', '31.13', '1', 'yes', 'southeast', '34806.4677'],
#  690: ['21', 'male', '27.36', '0', 'no', 'northeast', '2104.1134'],
#  691: ['47', 'male', '36.2', '1', 'no', 'southwest', '8068.185'],
# ...
#  770: ['61', 'male', '36.1', '3', 'no', 'southwest', '27941.28758'],
#  771: ['53', 'female', '26.7', '2', 'no', 'southwest', '11150.78'],
#  772: ['44', 'female', '36.48', '0', 'no', 'northeast', '12797.20962'],
#  773: ['19', 'female', '28.88', '0', 'yes', 'northwest', '17748.5062'],
#  774: ['41', 'male', '34.2', '2', 'no', 'northwest', '7261.741'],
#  775: ['51', 'male', '33.33', '3', 'no', 'southeast', '10560.4917'],
#  776: ['40', 'male', '32.3', '2', 'no', 'northwest', '6986.697'],
#  777: ['45', 'male', '39.805', '0', 'no', 'northeast', '7448.40395'],
#  778: ['35', 'male', '34.32', '3', 'no', 'southeast', '5934.3798'],
#  779: ['53', 'male', '28.88', '0', 'no', 'northwest', '9869.8102'],
#  780: ['30', 'male', '24.4', '3', 'yes', 'southwest', '18259.216'],
#  781: ['18', 'male', '41.14', '0', 'no', 'southeast', '1146.7966'],
#  782: ['51', 'male', '35.97', '1', 'no', 'southeast', '9386.1613'],
#  783: ['50', 'female', '27.6', '1', 'yes', 'southwest', '24520.264'],
#  784: ['31', 'female', '29.26', '1', 'no', 'southeast', '4350.5144'],
#  785: ['35', 'female', '27.7', '3', 'no', 'southwest', '6414.178'],
#  786: ['60', 'male', '36.955', '0', 'no', 'northeast', '12741.16745'],
#  787: ['21', 'male', '36.86', '0', 'no', 'northwest', '1917.3184'],
#  788: ['29', 'male', '22.515', '3', 'no', 'northeast', '5209.57885'],
#  789: ['62', 'female', '29.92', '0', 'no', 'southeast', '13457.9608'],
#  790: ['39', 'female', '41.8', '0', 'no', 'southeast', '5662.225'],
#  791: ['19', 'male', '27.6', '0', 'no', 'southwest', '1252.407'],
#  792: ['22', 'female', '23.18', '0', 'no', 'northeast', '2731.9122'],
#  793: ['53', 'male', '20.9', '0', 'yes', 'southeast', '21195.818'],
#  794: ['39', 'female', '31.92', '2', 'no', 'northwest', '7209.4918'],
#  795: ['27', 'male', '28.5', '0', 'yes', 'northwest', '18310.742'],
#  796: ['30', 'male', '44.22', '2', 'no', 'southeast', '4266.1658'],
#  797: ['30', 'female', '22.895', '1', 'no', 'northeast', '4719.52405'],
#  798: ['58', 'female', '33.1', '0', 'no', 'southwest', '11848.141'],
#  799: ['33', 'male', '24.795', '0', 'yes', 'northeast', '17904.52705'],
#  800: ['42', 'female', '26.18', '1', 'no', 'southeast', '7046.7222'],
#  801: ['64', 'female', '35.97', '0', 'no', 'southeast', '14313.8463'],
#  802: ['21', 'male', '22.3', '1', 'no', 'southwest', '2103.08'],
#  803: ['18', 'female', '42.24', '0', 'yes', 'southeast', '38792.6856'],
#  804: ['23', 'male', '26.51', '0', 'no', 'southeast', '1815.8759'],
#  805: ['45', 'female', '35.815', '0', 'no', 'northwest', '7731.85785'],
#  806: ['40', 'female', '41.42', '1', 'no', 'northwest', '28476.73499'],
#  807: ['19', 'female', '36.575', '0', 'no', 'northwest', '2136.88225'],
#  808: ['18', 'male', '30.14', '0', 'no', 'southeast', '1131.5066'],
#  809: ['25', 'male', '25.84', '1', 'no', 'northeast', '3309.7926'],
#  810: ['46', 'female', '30.8', '3', 'no', 'southwest', '9414.92'],
#  811: ['33', 'female', '42.94', '3', 'no', 'northwest', '6360.9936'],
#  812: ['54', 'male', '21.01', '2', 'no', 'southeast', '11013.7119'],
#  813: ['28', 'male', '22.515', '2', 'no', 'northeast', '4428.88785'],
#  814: ['36', 'male', '34.43', '2', 'no', 'southeast', '5584.3057'],
#  815: ['20', 'female', '31.46', '0', 'no', 'southeast', '1877.9294'],
#  816: ['24', 'female', '24.225', '0', 'no', 'northwest', '2842.76075'],
#  817: ['23', 'male', '37.1', '3', 'no', 'southwest', '3597.596'],
#  818: ['47', 'female', '26.125', '1', 'yes', 'northeast', '23401.30575'],
#  819: ['33', 'female', '35.53', '0', 'yes', 'northwest', '55135.40209'],
#  820: ['45', 'male', '33.7', '1', 'no', 'southwest', '7445.918'],
#  821: ['26', 'male', '17.67', '0', 'no', 'northwest', '2680.9493'],
#  822: ['18', 'female', '31.13', '0', 'no', 'southeast', '1621.8827'],
#  823: ['44', 'female', '29.81', '2', 'no', 'southeast', '8219.2039'],
#  824: ['60', 'male', '24.32', '0', 'no', 'northwest', '12523.6048'],
#  825: ['64', 'female', '31.825', '2', 'no', 'northeast', '16069.08475'],
#  826: ['56', 'male', '31.79', '2', 'yes', 'southeast', '43813.8661'],
#  827: ['36', 'male', '28.025', '1', 'yes', 'northeast', '20773.62775'],
#  828: ['41', 'male', '30.78', '3', 'yes', 'northeast', '39597.4072'],
#  829: ['39', 'male', '21.85', '1', 'no', 'northwest', '6117.4945'],
#  830: ['63', 'male', '33.1', '0', 'no', 'southwest', '13393.756'],
#  831: ['36', 'female', '25.84', '0', 'no', 'northwest', '5266.3656'],
#  832: ['28', 'female', '23.845', '2', 'no', 'northwest', '4719.73655'],
#  833: ['58', 'male', '34.39', '0', 'no', 'northwest', '11743.9341'],
#  834: ['36', 'male', '33.82', '1', 'no', 'northwest', '5377.4578'],
#  835: ['42', 'male', '35.97', '2', 'no', 'southeast', '7160.3303'],
#  836: ['36', 'male', '31.5', '0', 'no', 'southwest', '4402.233'],
#  837: ['56', 'female', '28.31', '0', 'no', 'northeast', '11657.7189'],
#  838: ['35', 'female', '23.465', '2', 'no', 'northeast', '6402.29135'],
#  839: ['59', 'female', '31.35', '0', 'no', 'northwest', '12622.1795'],
#  840: ['21', 'male', '31.1', '0', 'no', 'southwest', '1526.312'],
#  841: ['59', 'male', '24.7', '0', 'no', 'northeast', '12323.936'],
#  842: ['23', 'female', '32.78', '2', 'yes', 'southeast', '36021.0112'],
#  843: ['57', 'female', '29.81', '0', 'yes', 'southeast', '27533.9129'],
#  844: ['53', 'male', '30.495', '0', 'no', 'northeast', '10072.05505'],
#  845: ['60', 'female', '32.45', '0', 'yes', 'southeast', '45008.9555'],
#  846: ['51', 'female', '34.2', '1', 'no', 'southwest', '9872.701'],
#  847: ['23', 'male', '50.38', '1', 'no', 'southeast', '2438.0552'],
#  848: ['27', 'female', '24.1', '0', 'no', 'southwest', '2974.126'],
#  849: ['55', 'male', '32.775', '0', 'no', 'northwest', '10601.63225'],
#  850: ['37', 'female', '30.78', '0', 'yes', 'northeast', '37270.1512'],
#  851: ['61', 'male', '32.3', '2', 'no', 'northwest', '14119.62'],
#  852: ['46', 'female', '35.53', '0', 'yes', 'northeast', '42111.6647'],
#  853: ['53', 'female', '23.75', '2', 'no', 'northeast', '11729.6795'],
#  854: ['49', 'female', '23.845', '3', 'yes', 'northeast', '24106.91255'],
#  855: ['20', 'female', '29.6', '0', 'no', 'southwest', '1875.344'],
#  856: ['48', 'female', '33.11', '0', 'yes', 'southeast', '40974.1649'],
#  857: ['25', 'male', '24.13', '0', 'yes', 'northwest', '15817.9857'],
#  858: ['25', 'female', '32.23', '1', 'no', 'southeast', '18218.16139'],
#  859: ['57', 'male', '28.1', '0', 'no', 'southwest', '10965.446'],
#  860: ['37', 'female', '47.6', '2', 'yes', 'southwest', '46113.511'],
#  861: ['38', 'female', '28', '3', 'no', 'southwest', '7151.092'],
#  862: ['55', 'female', '33.535', '2', 'no', 'northwest', '12269.68865'],
#  863: ['36', 'female', '19.855', '0', 'no', 'northeast', '5458.04645'],
#  864: ['51', 'male', '25.4', '0', 'no', 'southwest', '8782.469'],
#  865: ['40', 'male', '29.9', '2', 'no', 'southwest', '6600.361'],
#  866: ['18', 'male', '37.29', '0', 'no', 'southeast', '1141.4451'],
#  867: ['57', 'male', '43.7', '1', 'no', 'southwest', '11576.13'],
#  868: ['61', 'male', '23.655', '0', 'no', 'northeast', '13129.60345'],
#  869: ['25', 'female', '24.3', '3', 'no', 'southwest', '4391.652'],
#  870: ['50', 'male', '36.2', '0', 'no', 'southwest', '8457.818'],
#  871: ['26', 'female', '29.48', '1', 'no', 'southeast', '3392.3652'],
#  872: ['42', 'male', '24.86', '0', 'no', 'southeast', '5966.8874'],
#  873: ['43', 'male', '30.1', '1', 'no', 'southwest', '6849.026'],
#  874: ['44', 'male', '21.85', '3', 'no', 'northeast', '8891.1395'],
#  875: ['23', 'female', '28.12', '0', 'no', 'northwest', '2690.1138'],
#  876: ['49', 'female', '27.1', '1', 'no', 'southwest', '26140.3603'],
#  877: ['33', 'male', '33.44', '5', 'no', 'southeast', '6653.7886'],
#  878: ['41', 'male', '28.8', '1', 'no', 'southwest', '6282.235'],
#  879: ['37', 'female', '29.5', '2', 'no', 'southwest', '6311.952'],
#  880: ['22', 'male', '34.8', '3', 'no', 'southwest', '3443.064'],
#  881: ['23', 'male', '27.36', '1', 'no', 'northwest', '2789.0574'],
#  882: ['21', 'female', '22.135', '0', 'no', 'northeast', '2585.85065'],
#  883: ['51', 'female', '37.05', '3', 'yes', 'northeast', '46255.1125'],
#  884: ['25', 'male', '26.695', '4', 'no', 'northwest', '4877.98105'],
#  885: ['32', 'male', '28.93', '1', 'yes', 'southeast', '19719.6947'],
#  886: ['57', 'male', '28.975', '0', 'yes', 'northeast', '27218.43725'],
#  887: ['36', 'female', '30.02', '0', 'no', 'northwest', '5272.1758'],
#  888: ['22', 'male', '39.5', '0', 'no', 'southwest', '1682.597'],
#  889: ['57', 'male', '33.63', '1', 'no', 'northwest', '11945.1327'],
#  890: ['64', 'female', '26.885', '0', 'yes', 'northwest', '29330.98315'],
#  891: ['36', 'female', '29.04', '4', 'no', 'southeast', '7243.8136'],
#  892: ['54', 'male', '24.035', '0', 'no', 'northeast', '10422.91665'],
#  893: ['47', 'male', '38.94', '2', 'yes', 'southeast', '44202.6536'],
#  894: ['62', 'male', '32.11', '0', 'no', 'northeast', '13555.0049'],
#  895: ['61', 'female', '44', '0', 'no', 'southwest', '13063.883'],
#  896: ['43', 'female', '20.045', '2', 'yes', 'northeast', '19798.05455'],
#  897: ['19', 'male', '25.555', '1', 'no', 'northwest', '2221.56445'],
#  898: ['18', 'female', '40.26', '0', 'no', 'southeast', '1634.5734'],
#  899: ['19', 'female', '22.515', '0', 'no', 'northwest', '2117.33885'],
#  900: ['49', 'male', '22.515', '0', 'no', 'northeast', '8688.85885'],
#  901: ['60', 'male', '40.92', '0', 'yes', 'southeast', '48673.5588'],
#  902: ['26', 'male', '27.265', '3', 'no', 'northeast', '4661.28635'],
#  903: ['49', 'male', '36.85', '0', 'no', 'southeast', '8125.7845'],
#  904: ['60', 'female', '35.1', '0', 'no', 'southwest', '12644.589'],
#  905: ['26', 'female', '29.355', '2', 'no', 'northeast', '4564.19145'],
#  906: ['27', 'male', '32.585', '3', 'no', 'northeast', '4846.92015'],
#  907: ['44', 'female', '32.34', '1', 'no', 'southeast', '7633.7206'],
#  908: ['63', 'male', '39.8', '3', 'no', 'southwest', '15170.069'],
#  909: ['32', 'female', '24.6', '0', 'yes', 'southwest', '17496.306'],
#  910: ['22', 'male', '28.31', '1', 'no', 'northwest', '2639.0429'],
#  911: ['18', 'male', '31.73', '0', 'yes', 'northeast', '33732.6867'],
#  912: ['59', 'female', '26.695', '3', 'no', 'northwest', '14382.70905'],
#  913: ['44', 'female', '27.5', '1', 'no', 'southwest', '7626.993'],
#  914: ['33', 'male', '24.605', '2', 'no', 'northwest', '5257.50795'],
#  915: ['24', 'female', '33.99', '0', 'no', 'southeast', '2473.3341'],
#  916: ['43', 'female', '26.885', '0', 'yes', 'northwest', '21774.32215'],
#  917: ['45', 'male', '22.895', '0', 'yes', 'northeast', '35069.37452'],
#  918: ['61', 'female', '28.2', '0', 'no', 'southwest', '13041.921'],
#  919: ['35', 'female', '34.21', '1', 'no', 'southeast', '5245.2269'],
#  920: ['62', 'female', '25', '0', 'no', 'southwest', '13451.122'],
#  921: ['62', 'female', '33.2', '0', 'no', 'southwest', '13462.52'],
#  922: ['38', 'male', '31', '1', 'no', 'southwest', '5488.262'],
#  923: ['34', 'male', '35.815', '0', 'no', 'northwest', '4320.41085'],
#  924: ['43', 'male', '23.2', '0', 'no', 'southwest', '6250.435'],
#  925: ['50', 'male', '32.11', '2', 'no', 'northeast', '25333.33284'],
#  926: ['19', 'female', '23.4', '2', 'no', 'southwest', '2913.569'],
#  927: ['57', 'female', '20.1', '1', 'no', 'southwest', '12032.326'],
#  928: ['62', 'female', '39.16', '0', 'no', 'southeast', '13470.8044'],
#  929: ['41', 'male', '34.21', '1', 'no', 'southeast', '6289.7549'],
#  930: ['26', 'male', '46.53', '1', 'no', 'southeast', '2927.0647'],
#  931: ['39', 'female', '32.5', '1', 'no', 'southwest', '6238.298'],
#  932: ['46', 'male', '25.8', '5', 'no', 'southwest', '10096.97'],
#  933: ['45', 'female', '35.3', '0', 'no', 'southwest', '7348.142'],
#  934: ['32', 'male', '37.18', '2', 'no', 'southeast', '4673.3922'],
#  935: ['59', 'female', '27.5', '0', 'no', 'southwest', '12233.828'],
#  936: ['44', 'male', '29.735', '2', 'no', 'northeast', '32108.66282'],
#  937: ['39', 'female', '24.225', '5', 'no', 'northwest', '8965.79575'],
#  938: ['18', 'male', '26.18', '2', 'no', 'southeast', '2304.0022'],
#  939: ['53', 'male', '29.48', '0', 'no', 'southeast', '9487.6442'],
#  940: ['18', 'male', '23.21', '0', 'no', 'southeast', '1121.8739'],
#  941: ['50', 'female', '46.09', '1', 'no', 'southeast', '9549.5651'],
#  942: ['18', 'female', '40.185', '0', 'no', 'northeast', '2217.46915'],
#  943: ['19', 'male', '22.61', '0', 'no', 'northwest', '1628.4709'],
#  944: ['62', 'male', '39.93', '0', 'no', 'southeast', '12982.8747'],
#  945: ['56', 'female', '35.8', '1', 'no', 'southwest', '11674.13'],
#  946: ['42', 'male', '35.8', '2', 'no', 'southwest', '7160.094'],
#  947: ['37', 'male', '34.2', '1', 'yes', 'northeast', '39047.285'],
#  948: ['42', 'male', '31.255', '0', 'no', 'northwest', '6358.77645'],
#  949: ['25', 'male', '29.7', '3', 'yes', 'southwest', '19933.458'],
#  950: ['57', 'male', '18.335', '0', 'no', 'northeast', '11534.87265'],
#  951: ['51', 'male', '42.9', '2', 'yes', 'southeast', '47462.894'],
#  952: ['30', 'female', '28.405', '1', 'no', 'northwest', '4527.18295'],
#  953: ['44', 'male', '30.2', '2', 'yes', 'southwest', '38998.546'],
#  954: ['34', 'male', '27.835', '1', 'yes', 'northwest', '20009.63365'],
#  955: ['31', 'male', '39.49', '1', 'no', 'southeast', '3875.7341'],
#  956: ['54', 'male', '30.8', '1', 'yes', 'southeast', '41999.52'],
#  957: ['24', 'male', '26.79', '1', 'no', 'northwest', '12609.88702'],
#  958: ['43', 'male', '34.96', '1', 'yes', 'northeast', '41034.2214'],
#  959: ['48', 'male', '36.67', '1', 'no', 'northwest', '28468.91901'],
#  960: ['19', 'female', '39.615', '1', 'no', 'northwest', '2730.10785'],
#  961: ['29', 'female', '25.9', '0', 'no', 'southwest', '3353.284'],
#  962: ['63', 'female', '35.2', '1', 'no', 'southeast', '14474.675'],
#  963: ['46', 'male', '24.795', '3', 'no', 'northeast', '9500.57305'],
#  964: ['52', 'male', '36.765', '2', 'no', 'northwest', '26467.09737'],
#  965: ['35', 'male', '27.1', '1', 'no', 'southwest', '4746.344'],
#  966: ['51', 'male', '24.795', '2', 'yes', 'northwest', '23967.38305'],
#  967: ['44', 'male', '25.365', '1', 'no', 'northwest', '7518.02535'],
#  968: ['21', 'male', '25.745', '2', 'no', 'northeast', '3279.86855'],
#  969: ['39', 'female', '34.32', '5', 'no', 'southeast', '8596.8278'],
#  970: ['50', 'female', '28.16', '3', 'no', 'southeast', '10702.6424'],
#  971: ['34', 'female', '23.56', '0', 'no', 'northeast', '4992.3764'],
#  972: ['22', 'female', '20.235', '0', 'no', 'northwest', '2527.81865'],
#  973: ['19', 'female', '40.5', '0', 'no', 'southwest', '1759.338'],
#  974: ['26', 'male', '35.42', '0', 'no', 'southeast', '2322.6218'],
#  975: ['29', 'male', '22.895', '0', 'yes', 'northeast', '16138.76205'],
#  976: ['48', 'male', '40.15', '0', 'no', 'southeast', '7804.1605'],
#  977: ['26', 'male', '29.15', '1', 'no', 'southeast', '2902.9065'],
#  978: ['45', 'female', '39.995', '3', 'no', 'northeast', '9704.66805'],
#  979: ['36', 'female', '29.92', '0', 'no', 'southeast', '4889.0368'],
#  980: ['54', 'male', '25.46', '1', 'no', 'northeast', '25517.11363'],
#  981: ['34', 'male', '21.375', '0', 'no', 'northeast', '4500.33925'],
#  982: ['31', 'male', '25.9', '3', 'yes', 'southwest', '19199.944'],
#  983: ['27', 'female', '30.59', '1', 'no', 'northeast', '16796.41194'],
#  984: ['20', 'male', '30.115', '5', 'no', 'northeast', '4915.05985'],
#  985: ['44', 'female', '25.8', '1', 'no', 'southwest', '7624.63'],
#  986: ['43', 'male', '30.115', '3', 'no', 'northwest', '8410.04685'],
#  987: ['45', 'female', '27.645', '1', 'no', 'northwest', '28340.18885'],
#  988: ['34', 'male', '34.675', '0', 'no', 'northeast', '4518.82625'],
#  989: ['24', 'female', '20.52', '0', 'yes', 'northeast', '14571.8908'],
#  990: ['26', 'female', '19.8', '1', 'no', 'southwest', '3378.91'],
#  991: ['38', 'female', '27.835', '2', 'no', 'northeast', '7144.86265'],
#  992: ['50', 'female', '31.6', '2', 'no', 'southwest', '10118.424'],
#  993: ['38', 'male', '28.27', '1', 'no', 'southeast', '5484.4673'],
#  994: ['27', 'female', '20.045', '3', 'yes', 'northwest', '16420.49455'],
#  995: ['39', 'female', '23.275', '3', 'no', 'northeast', '7986.47525'],
#  996: ['39', 'female', '34.1', '3', 'no', 'southwest', '7418.522'],
#  997: ['63', 'female', '36.85', '0', 'no', 'southeast', '13887.9685'],
#  998: ['33', 'female', '36.29', '3', 'no', 'northeast', '6551.7501'],
#  999: ['36', 'female', '26.885', '0', 'no', 'northwest', '5267.81815'],
#  ...}
